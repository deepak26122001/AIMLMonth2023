# %% [markdown]
# # EDA - Breast Cancer - Deepak Chaudhary

# %%
#importing libraries
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Breast_cancer_data.csv")

# %%
print(df)
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 0            0
# 1            0
# 2            0
# ...

# %%
#to print upper portions only as the data is too long we will use
df.head()
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    diagnosis
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# i will obtain the information of the data to detect the null values as well
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean_radius      569 non-null    float64
#  1   mean_texture     569 non-null    float64
#  2   mean_perimeter   569 non-null    float64
#  3   mean_area        569 non-null    float64
#  4   mean_smoothness  569 non-null    float64
#  5   diagnosis        569 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 26.8 KB

# %%
# I see there are no null values here but lets check if still there are null values in the columns as well
df.isna().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
#we find that there are no columns for null values
# determining the shape of the given data can be given as
df.shape
# Out:
# (569, 6)

# %%
df.describe()
# Out:
#        mean_radius  mean_texture  mean_perimeter    mean_area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean_smoothness   diagnosis
# count       569.000000  569.000000
# mean          0.096360    0.627417
# std           0.014064    0.483918
# min           0.052630    0.000000
# 25%           0.086370    0.000000
# 50%           0.095870    1.000000
# 75%           0.105300    1.000000
# max           0.163400    1.000000

# %%
#I will analyse the data of daignosis in visual form also 
df['diagnosis'].value_counts()
# Out:
# 1    357
# 0    212
# Name: diagnosis, dtype: int64

# %%
#plot it in the graph we see that
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df.iloc[:,1:4])

# %%
df.iloc[:,1:6].corr()
# Out:
#                  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# mean_texture         1.000000        0.329533   0.321086        -0.023389
# mean_perimeter       0.329533        1.000000   0.986507         0.207278
# mean_area            0.321086        0.986507   1.000000         0.177028
# mean_smoothness     -0.023389        0.207278   0.177028         1.000000
# diagnosis           -0.415185       -0.742636  -0.708984        -0.358560
#
#                  diagnosis
# mean_texture     -0.415185
# mean_perimeter   -0.742636
# mean_area        -0.708984
# mean_smoothness  -0.358560
# diagnosis         1.000000

# %%
#visualise the correlation
plt.figure(figsize=(5,5))
sns.heatmap(df.iloc[:,1:6].corr(),annot=True,fmt=".0%")
# Out:
# <Axes: >

# %%
x=df.iloc[:,2:6].values
y=df.iloc[:,1].values

# %%
print(x)
# Out:
# [[1.228e+02 1.001e+03 1.184e-01 0.000e+00]
#  [1.329e+02 1.326e+03 8.474e-02 0.000e+00]
#  [1.300e+02 1.203e+03 1.096e-01 0.000e+00]
#  ...
#  [1.083e+02 8.581e+02 8.455e-02 0.000e+00]
#  [1.401e+02 1.265e+03 1.178e-01 0.000e+00]
#  [4.792e+01 1.810e+02 5.263e-02 1.000e+00]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20, random_state = 0)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

# %%
#Here This was the Exploratory Data Analysis of Breast Cancer Prediction- This made us realise that it is so important'
#to break the data into chunks to make our model learn various tactics of analysing the situation well
#these important libraries really helps model and user understand the situation given in the data
#EDA plays really a key role in the development of any model in machine learning
